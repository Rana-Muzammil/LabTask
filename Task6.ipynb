# %%
height = float(input("Enter the height in inches : "));
weight = float(input("enter the weight in pounds : "));

b_m_i =  (weight*703)/(height**2);

if(b_m_i < 18.5):
    print("Person is underweight.");
    
elif(b_m_i >= 18.5 and b_m_i <= 25):
    print("Weight is optimal.");
    
elif(b_m_i > 25):
    print("Body is overweight.");
# Out:
# Enter the height in inches : 7
# enter the weight in pounds : 7
# Body is overweight.
