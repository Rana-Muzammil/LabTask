# %%
i = 0;
j = 0;
for i in range(6):

    gallons = float(input("Enter the gallon used (-1 to end) : "));
   
    if(gallons != -1):

        miles = float(input("Enter the miles driven : "));
        overall = miles / gallons;
        print("The miles/gallon for this tank was : ", miles / gallons);

        i+= overall;
        j+= 1;
        
    elif(gallons == -1):

        print("The overall average miles/gallon was : ",i / j);
# Out:
# Enter the gallon used (-1 to end) : 33
# Enter the miles driven : 74
# The miles/gallon for this tank was :  2.242424242424242
# Enter the gallon used (-1 to end) : 54
# Enter the miles driven : 789
# The miles/gallon for this tank was :  14.61111111111111
# Enter the gallon used (-1 to end) : 41
# Enter the miles driven : 456
# The miles/gallon for this tank was :  11.121951219512194
# Enter the gallon used (-1 to end) : 23
# Enter the miles driven : 2147
# The miles/gallon for this tank was :  93.34782608695652
# Enter the gallon used (-1 to end) : 745
# Enter the miles driven : 74
# The miles/gallon for this tank was :  0.09932885906040269
# Enter the gallon used (-1 to end) : 745
# Enter the miles driven : 7458
# The miles/gallon for this tank was :  10.010738255033557

# %% [markdown]
# ###
