# %%
body_mass = float(input("Enter the body mass : "));

weight = body_mass * 9.80;

if(weight > 500):

    print("Weight is too heavy.");

elif(weight < 100):

    print("Weigth is too light");

else:

    print("not greater than 500 or nor less than 100.");
# Out:
# Enter the body mass : 85
# Weight is too heavy.
